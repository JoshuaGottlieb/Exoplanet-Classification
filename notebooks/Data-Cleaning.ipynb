# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/raw/kepler_cumulative.csv')

# %%
df
# Out:
#        koi_name   planet_name     disposition  \
# 0     K00752.01  Kepler-227 b       CONFIRMED
# 1     K00752.02  Kepler-227 c       CONFIRMED
# 2     K00753.01           NaN       CANDIDATE
# 3     K00754.01           NaN  FALSE POSITIVE
# 4     K00755.01  Kepler-664 b       CONFIRMED
# ...         ...           ...             ...
# 9559  K07985.01           NaN  FALSE POSITIVE
# 9560  K07986.01           NaN       CANDIDATE
# 9561  K07987.01           NaN  FALSE POSITIVE
# 9562  K07988.01           NaN       CANDIDATE
# 9563  K07989.01           NaN  FALSE POSITIVE
#
#                                     false_positive_type ml_fittype   star_id  \
# 0                                            NO_COMMENT    LS+MCMC  10797460
# 1                                            NO_COMMENT    LS+MCMC  10797460
# 2                                         DEEP_V_SHAPED    LS+MCMC  10811496
# 3      MOD_ODDEVEN_DV---MOD_ODDEVEN_ALT---DEEP_V_SHAPED    LS+MCMC  10848459
# 4                                            NO_COMMENT    LS+MCMC  10854555
# ...                                                 ...        ...       ...
# 9559  MOD_SEC_DV---PLANET_OCCULT_DV---MOD_SEC_ALT---...    LS+MCMC  10090151
# 9560                                         NO_COMMENT    LS+MCMC  10128825
# 9561                               CENT_RESOLVED_OFFSET    LS+MCMC  10147276
# 9562                  ALL_TRANS_CHASES---CENT_SATURATED    LS+MCMC  10155286
# 9563    CENT_RESOLVED_OFFSET---HALO_GHOST---EPHEM_MATCH    LS+MCMC  10156110
#
#       num_of_objects_around_star  fp_not_transit  fp_stellar_eclipse  \
# 0                              2               0                   0
# 1                              2               0                   0
# 2                              1               0                   0
# 3                              1               0                   1
# 4                              1               0                   0
# ...                          ...             ...                 ...
# 9559                           1               0                   1
# 9560                           1               0                   0
# 9561                           1               0                   0
# 9562                           1               0                   0
# 9563                           1               0                   0
#
#       fp_centroid_offset  ...  centroid_right_ascension_offset  \
# 0                      0  ...                            0.430
# 1                      0  ...                           -0.630
# 2                      0  ...                           -0.021
# 3                      0  ...                           -0.111
# 4                      0  ...                           -0.010
# ...                  ...  ...                              ...
# 9559                   1  ...                            0.792
# 9560                   0  ...                            0.100
# 9561                   1  ...                            7.200
# 9562                   0  ...                            0.310
# 9563                   1  ...                            2.900
#
#       centroid_declination_offset  planet_star_right_ascension_offset  \
# 0                           0.940                           -0.000200
# 1                           1.230                            0.000660
# 2                          -0.038                            0.000700
# 3                           0.002                            0.003020
# 4                           0.230                            0.000080
# ...                           ...                                 ...
# 9559                       -0.484                           -0.000237
# 9560                        2.000                           -0.000018
# 9561                       -5.600                           -0.000720
# 9562                        0.010                           -0.000290
# 9563                        8.900                           -0.000230
#
#       planet_star_declination_offset  angular_offset_right_ascension  \
# 0                          -0.000550                          -0.010
# 1                          -0.001050                           0.390
# 2                           0.000600                          -0.025
# 3                          -0.001420                          -0.249
# 4                          -0.000070                           0.030
# ...                              ...                             ...
# 9559                        0.000178                           2.132
# 9560                       -0.000074                           0.740
# 9561                        0.000500                           3.410
# 9562                       -0.000100                           1.061
# 9563                       -0.000700                           1.020
#
#       angular_offset_declination  angular_offset_sky  insolation_flux  \
# 0                          0.200               0.200            93.59
# 1                          0.000               0.390             9.11
# 2                         -0.034               0.042            39.30
# 3                          0.147               0.289           891.96
# 4                         -0.090               0.100           926.16
# ...                          ...                 ...              ...
# 9559                      -1.757               2.763          4500.53
# 9560                      -0.250               0.780          1585.81
# 9561                      -3.650               5.000          5713.41
# 9562                       1.320               1.690            22.68
# 9563                       3.300               3.400           607.42
#
#       star_density  disposition_score
# 0          3.20796              1.000
# 1          3.02368              0.969
# 2          7.29555              0.000
# 3          0.22080              0.000
# 4          1.98635              1.000
# ...            ...                ...
# 9559       0.16318              0.000
# 9560       0.50770              0.497
# 9561       8.97692              0.021
# 9562      85.88623              0.092
# 9563       1.40645              0.000
#
# [9564 rows x 59 columns]

# %%
df.drop('planet_name', axis = 1, inplace = True)

# %%
df['fp_total'] = df.fp_not_transit + df.fp_stellar_eclipse + df.fp_centroid_offset + df.fp_contamination

# %%
df.fp_total.value_counts()
# Out:
# 0      4799
# 1      3230
# 2      1042
# 3       489
# 4         3
# 465       1
# Name: fp_total, dtype: int64

# %%
multi_class_df = df.loc[((df.fp_total <= 1) & (df.disposition == 'FALSE POSITIVE')) | (df.disposition == 'CONFIRMED')].copy()

# %%
multi_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5976 entries, 0 to 9561
# Data columns (total 59 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   koi_name                            5976 non-null   object
#  1   disposition                         5976 non-null   object
#  2   false_positive_type                 5336 non-null   object
#  3   ml_fittype                          5976 non-null   object
#  4   star_id                             5976 non-null   int64
#  5   num_of_objects_around_star          5976 non-null   int64
#  6   fp_not_transit                      5976 non-null   int64
#  7   fp_stellar_eclipse                  5976 non-null   int64
#  8   fp_centroid_offset                  5976 non-null   int64
#  9   fp_contamination                    5976 non-null   int64
#  10  right_ascension                     5976 non-null   float64
#  11  declination                         5976 non-null   float64
#  12  g_band_mag                          5956 non-null   float64
#  13  r_band_mag                          5974 non-null   float64
#  14  i_band_mag                          5865 non-null   float64
#  15  z_band_mag                          5560 non-null   float64
#  16  j_band_mag                          5958 non-null   float64
#  17  h_band_mag                          5958 non-null   float64
#  18  k_band_mag                          5958 non-null   float64
#  19  kepler_band_mag                     5975 non-null   float64
#  20  num_of_transits                     5339 non-null   float64
#  21  max_single_event_stat               5339 non-null   float64
#  22  max_multi_event_stat                5339 non-null   float64
#  23  odd_even_depth_stat                 5160 non-null   float64
#  24  limb_dark_co4                       5742 non-null   float64
#  25  limb_dark_co3                       5742 non-null   float64
#  26  limb_dark_co2                       5742 non-null   float64
#  27  limb_dark_co1                       5742 non-null   float64
#  28  transit_signal_to_noise             5742 non-null   float64
#  29  transit_epoch                       5976 non-null   float64
#  30  planet_radius_earth                 5742 non-null   float64
#  31  orbit_semimajor_axis                5742 non-null   float64
#  32  impact                              5742 non-null   float64
#  33  transit_duration                    5976 non-null   float64
#  34  transit_depth                       5742 non-null   float64
#  35  orbital_period                      5976 non-null   float64
#  36  planet_star_radius_ratio            5742 non-null   float64
#  37  planet_star_distance_radius         5742 non-null   float64
#  38  inclination                         5741 non-null   float64
#  39  planet_temp                         5742 non-null   float64
#  40  star_temp                           5742 non-null   float64
#  41  star_surface_gravity                5742 non-null   float64
#  42  star_metallicity                    5727 non-null   float64
#  43  star_radius                         5742 non-null   float64
#  44  star_mass                           5742 non-null   float64
#  45  flux_weight_offset_sig              5217 non-null   float64
#  46  centroid_right_ascension            5633 non-null   float64
#  47  centroid_declination                5633 non-null   float64
#  48  centroid_right_ascension_offset     5647 non-null   float64
#  49  centroid_declination_offset         5647 non-null   float64
#  50  planet_star_right_ascension_offset  5379 non-null   float64
#  51  planet_star_declination_offset      5404 non-null   float64
#  52  angular_offset_right_ascension      5609 non-null   float64
#  53  angular_offset_declination          5609 non-null   float64
#  54  angular_offset_sky                  5609 non-null   float64
#  55  insolation_flux                     5775 non-null   float64
#  56  star_density                        5775 non-null   float64
#  57  disposition_score                   5160 non-null   float64
#  58  fp_total                            5976 non-null   int64
# dtypes: float64(48), int64(7), object(4)
# memory usage: 2.7+ MB

# %%
multi_class_df.dropna(inplace = True)

# %%
multi_class_df = multi_class_df.loc[~((multi_class_df.disposition == 'FALSE POSITIVE')
                                      & ~(multi_class_df.fp_not_transit) & ~(multi_class_df.fp_stellar_eclipse)
                                      & ~(multi_class_df.fp_centroid_offset) & ~(multi_class_df.fp_contamination))]\
                                        .copy()

# %%
def encode_disposition(row):
    if row.disposition == 'CONFIRMED':
        return 0
    if row.fp_not_transit:
        return 1
    elif row.fp_stellar_eclipse:
        return 2
    elif row.fp_centroid_offset:
        return 3
    elif row.fp_contamination:
        return 4
    
multi_class_df['classification'] = multi_class_df.apply(lambda x: int(encode_disposition(x)), axis = 1)

# %%
multi_class_df.drop(['koi_name', 'false_positive_type', 'fp_total', 'disposition',
                     'fp_not_transit', 'fp_stellar_eclipse', 'fp_centroid_offset', 'fp_contamination'],
                    axis = 1, inplace = True)

# %%
multi_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4260 entries, 0 to 9561
# Data columns (total 52 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ml_fittype                          4260 non-null   object
#  1   star_id                             4260 non-null   int64
#  2   num_of_objects_around_star          4260 non-null   int64
#  3   right_ascension                     4260 non-null   float64
#  4   declination                         4260 non-null   float64
#  5   g_band_mag                          4260 non-null   float64
#  6   r_band_mag                          4260 non-null   float64
#  7   i_band_mag                          4260 non-null   float64
#  8   z_band_mag                          4260 non-null   float64
#  9   j_band_mag                          4260 non-null   float64
#  10  h_band_mag                          4260 non-null   float64
#  11  k_band_mag                          4260 non-null   float64
#  12  kepler_band_mag                     4260 non-null   float64
#  13  num_of_transits                     4260 non-null   float64
#  14  max_single_event_stat               4260 non-null   float64
#  15  max_multi_event_stat                4260 non-null   float64
#  16  odd_even_depth_stat                 4260 non-null   float64
#  17  limb_dark_co4                       4260 non-null   float64
#  18  limb_dark_co3                       4260 non-null   float64
#  19  limb_dark_co2                       4260 non-null   float64
#  20  limb_dark_co1                       4260 non-null   float64
#  21  transit_signal_to_noise             4260 non-null   float64
#  22  transit_epoch                       4260 non-null   float64
#  23  planet_radius_earth                 4260 non-null   float64
#  24  orbit_semimajor_axis                4260 non-null   float64
#  25  impact                              4260 non-null   float64
#  26  transit_duration                    4260 non-null   float64
#  27  transit_depth                       4260 non-null   float64
#  28  orbital_period                      4260 non-null   float64
#  29  planet_star_radius_ratio            4260 non-null   float64
#  30  planet_star_distance_radius         4260 non-null   float64
#  31  inclination                         4260 non-null   float64
#  32  planet_temp                         4260 non-null   float64
#  33  star_temp                           4260 non-null   float64
#  34  star_surface_gravity                4260 non-null   float64
#  35  star_metallicity                    4260 non-null   float64
#  36  star_radius                         4260 non-null   float64
#  37  star_mass                           4260 non-null   float64
#  38  flux_weight_offset_sig              4260 non-null   float64
#  39  centroid_right_ascension            4260 non-null   float64
#  40  centroid_declination                4260 non-null   float64
#  41  centroid_right_ascension_offset     4260 non-null   float64
#  42  centroid_declination_offset         4260 non-null   float64
#  43  planet_star_right_ascension_offset  4260 non-null   float64
#  44  planet_star_declination_offset      4260 non-null   float64
#  45  angular_offset_right_ascension      4260 non-null   float64
#  46  angular_offset_declination          4260 non-null   float64
#  47  angular_offset_sky                  4260 non-null   float64
#  48  insolation_flux                     4260 non-null   float64
#  49  star_density                        4260 non-null   float64
#  50  disposition_score                   4260 non-null   float64
#  51  classification                      4260 non-null   int64
# dtypes: float64(48), int64(3), object(1)
# memory usage: 1.7+ MB

# %%
binary_class_df = df.loc[(df.disposition == 'CONFIRMED') | (df.disposition == 'FALSE POSITIVE')].copy()

# %%
binary_class_df
# Out:
#        koi_name   planet_name     disposition  \
# 0     K00752.01  Kepler-227 b       CONFIRMED
# 1     K00752.02  Kepler-227 c       CONFIRMED
# 3     K00754.01           NaN  FALSE POSITIVE
# 4     K00755.01  Kepler-664 b       CONFIRMED
# 5     K00756.01  Kepler-228 d       CONFIRMED
# ...         ...           ...             ...
# 9557  K08198.01           NaN  FALSE POSITIVE
# 9558  K07984.01           NaN  FALSE POSITIVE
# 9559  K07985.01           NaN  FALSE POSITIVE
# 9561  K07987.01           NaN  FALSE POSITIVE
# 9563  K07989.01           NaN  FALSE POSITIVE
#
#                                     false_positive_type ml_fittype   star_id  \
# 0                                            NO_COMMENT    LS+MCMC  10797460
# 1                                            NO_COMMENT    LS+MCMC  10797460
# 3      MOD_ODDEVEN_DV---MOD_ODDEVEN_ALT---DEEP_V_SHAPED    LS+MCMC  10848459
# 4                                            NO_COMMENT    LS+MCMC  10854555
# 5                                            NO_COMMENT    LS+MCMC  10872983
# ...                                                 ...        ...       ...
# 9557  ALL_TRANS_CHASES---INCONSISTENT_TRANS---CENT_F...    LS+MCMC  10205598
# 9558                                        EPHEM_MATCH    LS+MCMC  10031643
# 9559  MOD_SEC_DV---PLANET_OCCULT_DV---MOD_SEC_ALT---...    LS+MCMC  10090151
# 9561                               CENT_RESOLVED_OFFSET    LS+MCMC  10147276
# 9563    CENT_RESOLVED_OFFSET---HALO_GHOST---EPHEM_MATCH    LS+MCMC  10156110
#
#       num_of_objects_around_star  fp_not_transit  fp_stellar_eclipse  \
# 0                              2               0                   0
# 1                              2               0                   0
# 3                              1               0                   1
# 4                              1               0                   0
# 5                              3               0                   0
# ...                          ...             ...                 ...
# 9557                           1               1                   0
# 9558                           1               0                   0
# 9559                           1               0                   1
# 9561                           1               0                   0
# 9563                           1               0                   0
#
#       fp_centroid_offset  ...  centroid_declination_offset  \
# 0                      0  ...                        0.940
# 1                      0  ...                        1.230
# 3                      0  ...                        0.002
# 4                      0  ...                        0.230
# 5                      0  ...                        0.140
# ...                  ...  ...                          ...
# 9557                   0  ...                       -0.300
# 9558                   0  ...                        1.200
# 9559                   1  ...                       -0.484
# 9561                   1  ...                       -5.600
# 9563                   1  ...                        8.900
#
#       planet_star_right_ascension_offset  planet_star_declination_offset  \
# 0                              -0.000200                       -0.000550
# 1                               0.000660                       -0.001050
# 3                               0.003020                       -0.001420
# 4                               0.000080                       -0.000070
# 5                               0.000040                             NaN
# ...                                  ...                             ...
# 9557                            0.000600                        0.000300
# 9558                           -0.000080                       -0.000100
# 9559                           -0.000237                        0.000178
# 9561                           -0.000720                        0.000500
# 9563                           -0.000230                       -0.000700
#
#       angular_offset_right_ascension  angular_offset_declination  \
# 0                             -0.010                       0.200
# 1                              0.390                       0.000
# 3                             -0.249                       0.147
# 4                              0.030                      -0.090
# 5                              0.040                      -0.070
# ...                              ...                         ...
# 9557                           2.360                      -0.990
# 9558                           1.260                      -1.200
# 9559                           2.132                      -1.757
# 9561                           3.410                      -3.650
# 9563                           1.020                       3.300
#
#       angular_offset_sky  insolation_flux  star_density  disposition_score  \
# 0                  0.200            93.59       3.20796              1.000
# 1                  0.390             9.11       3.02368              0.969
# 3                  0.289           891.96       0.22080              0.000
# 4                  0.100           926.16       1.98635              1.000
# 5                  0.080           114.81       0.67324              1.000
# ...                  ...              ...           ...                ...
# 9557               2.550             0.42       0.00771              0.008
# 9558               1.750           176.40       0.18863              0.000
# 9559               2.763          4500.53       0.16318              0.000
# 9561               5.000          5713.41       8.97692              0.021
# 9563               3.400           607.42       1.40645              0.000
#
#       fp_total
# 0            0
# 1            0
# 3            1
# 4            0
# 5            0
# ...        ...
# 9557         1
# 9558         1
# 9559         2
# 9561         1
# 9563         2
#
# [7510 rows x 60 columns]
