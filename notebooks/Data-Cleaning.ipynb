# %% [markdown]
# # Import Packages

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Load Dataframe

# %%
# Load in dataframe from csv
df = pd.read_csv('../data/raw/kepler_cumulative.csv')
df
# Out:
#        koi_name     disposition  \
# 0     K00752.01       CONFIRMED
# 1     K00752.02       CONFIRMED
# 2     K00753.01       CANDIDATE
# 3     K00754.01  FALSE POSITIVE
# 4     K00755.01       CONFIRMED
# ...         ...             ...
# 9559  K07985.01  FALSE POSITIVE
# 9560  K07986.01       CANDIDATE
# 9561  K07987.01  FALSE POSITIVE
# 9562  K07988.01       CANDIDATE
# 9563  K07989.01  FALSE POSITIVE
#
#                                     false_positive_type ml_fittype  \
# 0                                            NO_COMMENT    LS+MCMC
# 1                                            NO_COMMENT    LS+MCMC
# 2                                         DEEP_V_SHAPED    LS+MCMC
# 3      MOD_ODDEVEN_DV---MOD_ODDEVEN_ALT---DEEP_V_SHAPED    LS+MCMC
# 4                                            NO_COMMENT    LS+MCMC
# ...                                                 ...        ...
# 9559  MOD_SEC_DV---PLANET_OCCULT_DV---MOD_SEC_ALT---...    LS+MCMC
# 9560                                         NO_COMMENT    LS+MCMC
# 9561                               CENT_RESOLVED_OFFSET    LS+MCMC
# 9562                  ALL_TRANS_CHASES---CENT_SATURATED    LS+MCMC
# 9563    CENT_RESOLVED_OFFSET---HALO_GHOST---EPHEM_MATCH    LS+MCMC
#
#       num_of_objects_around_star  fp_not_transit  fp_stellar_eclipse  \
# 0                              2               0                   0
# 1                              2               0                   0
# 2                              1               0                   0
# 3                              1               0                   1
# 4                              1               0                   0
# ...                          ...             ...                 ...
# 9559                           1               0                   1
# 9560                           1               0                   0
# 9561                           1               0                   0
# 9562                           1               0                   0
# 9563                           1               0                   0
#
#       fp_centroid_offset  fp_contamination  right_ascension  ...  \
# 0                      0                 0        291.93423  ...
# 1                      0                 0        291.93423  ...
# 2                      0                 0        297.00482  ...
# 3                      0                 0        285.53461  ...
# 4                      0                 0        288.75488  ...
# ...                  ...               ...              ...  ...
# 9559                   1                 0        297.18875  ...
# 9560                   0                 0        286.50937  ...
# 9561                   1                 0        294.16489  ...
# 9562                   0                 0        296.76288  ...
# 9563                   1                 1        297.00977  ...
#
#       centroid_declination  centroid_right_ascension_offset  \
# 0                48.141910                            0.430
# 1                48.141990                           -0.630
# 2                48.134120                           -0.021
# 3                48.285210                           -0.111
# 4                48.226260                           -0.010
# ...                    ...                              ...
# 9559             47.093686                            0.792
# 9560             47.163770                            0.100
# 9561             47.174720                            7.200
# 9562             47.145142                            0.310
# 9563             47.123490                            2.900
#
#       centroid_declination_offset  planet_star_right_ascension_offset  \
# 0                           0.940                           -0.000200
# 1                           1.230                            0.000660
# 2                          -0.038                            0.000700
# 3                           0.002                            0.003020
# 4                           0.230                            0.000080
# ...                           ...                                 ...
# 9559                       -0.484                           -0.000237
# 9560                        2.000                           -0.000018
# 9561                       -5.600                           -0.000720
# 9562                        0.010                           -0.000290
# 9563                        8.900                           -0.000230
#
#       planet_star_declination_offset  angular_offset_right_ascension  \
# 0                          -0.000550                          -0.010
# 1                          -0.001050                           0.390
# 2                           0.000600                          -0.025
# 3                          -0.001420                          -0.249
# 4                          -0.000070                           0.030
# ...                              ...                             ...
# 9559                        0.000178                           2.132
# 9560                       -0.000074                           0.740
# 9561                        0.000500                           3.410
# 9562                       -0.000100                           1.061
# 9563                       -0.000700                           1.020
#
#       angular_offset_declination  angular_offset_sky  insolation_flux  \
# 0                          0.200               0.200            93.59
# 1                          0.000               0.390             9.11
# 2                         -0.034               0.042            39.30
# 3                          0.147               0.289           891.96
# 4                         -0.090               0.100           926.16
# ...                          ...                 ...              ...
# 9559                      -1.757               2.763          4500.53
# 9560                      -0.250               0.780          1585.81
# 9561                      -3.650               5.000          5713.41
# 9562                       1.320               1.690            22.68
# 9563                       3.300               3.400           607.42
#
#       star_density
# 0          3.20796
# 1          3.02368
# 2          7.29555
# 3          0.22080
# 4          1.98635
# ...            ...
# 9559       0.16318
# 9560       0.50770
# 9561       8.97692
# 9562      85.88623
# 9563       1.40645
#
# [9564 rows x 56 columns]

# %% [markdown]
# # Split Into Data into Subsets

# %%
# Creating a row representing the total number of false positive flags marked true for each record
df['fp_total'] = df.fp_not_transit + df.fp_stellar_eclipse + df.fp_centroid_offset + df.fp_contamination
df.fp_total.value_counts()
# Out:
# 0      4799
# 1      3230
# 2      1042
# 3       489
# 4         3
# 465       1
# Name: fp_total, dtype: int64

# %%
# Split df into two datasets - one for multiclass classification and one for binary class classification
# In order to have clearly disjoint classes in the multiclass case, choose only those with a confirmed disposition
# or those which have a false positive disposition and only 1 false positive flag set
multi_class_df = df.loc[((df.fp_total == 1) & (df.disposition == 'FALSE POSITIVE')) | (df.disposition == 'CONFIRMED')].copy()
binary_class_df = df.loc[(df.disposition == 'CONFIRMED') | (df.disposition == 'FALSE POSITIVE')].copy()

# %% [markdown]
# # Clean Multi-class Dataset

# %%
# Inspect multi_class_df
multi_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5881 entries, 0 to 9561
# Data columns (total 57 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   koi_name                            5881 non-null   object
#  1   disposition                         5881 non-null   object
#  2   false_positive_type                 5335 non-null   object
#  3   ml_fittype                          5881 non-null   object
#  4   num_of_objects_around_star          5881 non-null   int64
#  5   fp_not_transit                      5881 non-null   int64
#  6   fp_stellar_eclipse                  5881 non-null   int64
#  7   fp_centroid_offset                  5881 non-null   int64
#  8   fp_contamination                    5881 non-null   int64
#  9   right_ascension                     5881 non-null   float64
#  10  declination                         5881 non-null   float64
#  11  g_band_mag                          5863 non-null   float64
#  12  r_band_mag                          5879 non-null   float64
#  13  i_band_mag                          5774 non-null   float64
#  14  z_band_mag                          5476 non-null   float64
#  15  j_band_mag                          5863 non-null   float64
#  16  h_band_mag                          5863 non-null   float64
#  17  k_band_mag                          5863 non-null   float64
#  18  kepler_band_mag                     5880 non-null   float64
#  19  num_of_transits                     5338 non-null   float64
#  20  max_single_event_stat               5338 non-null   float64
#  21  max_multi_event_stat                5338 non-null   float64
#  22  odd_even_depth_stat                 5159 non-null   float64
#  23  limb_dark_co4                       5694 non-null   float64
#  24  limb_dark_co3                       5694 non-null   float64
#  25  limb_dark_co2                       5694 non-null   float64
#  26  limb_dark_co1                       5694 non-null   float64
#  27  transit_signal_to_noise             5694 non-null   float64
#  28  transit_epoch                       5881 non-null   float64
#  29  planet_radius_earth                 5694 non-null   float64
#  30  orbit_semimajor_axis                5694 non-null   float64
#  31  impact                              5694 non-null   float64
#  32  transit_duration                    5881 non-null   float64
#  33  transit_depth                       5694 non-null   float64
#  34  orbital_period                      5881 non-null   float64
#  35  planet_star_radius_ratio            5694 non-null   float64
#  36  planet_star_distance_radius         5694 non-null   float64
#  37  inclination                         5693 non-null   float64
#  38  planet_temp                         5694 non-null   float64
#  39  star_temp                           5694 non-null   float64
#  40  star_surface_gravity                5694 non-null   float64
#  41  star_metallicity                    5680 non-null   float64
#  42  star_radius                         5694 non-null   float64
#  43  star_mass                           5694 non-null   float64
#  44  flux_weight_offset_sig              5208 non-null   float64
#  45  centroid_right_ascension            5624 non-null   float64
#  46  centroid_declination                5624 non-null   float64
#  47  centroid_right_ascension_offset     5638 non-null   float64
#  48  centroid_declination_offset         5638 non-null   float64
#  49  planet_star_right_ascension_offset  5370 non-null   float64
#  50  planet_star_declination_offset      5395 non-null   float64
#  51  angular_offset_right_ascension      5601 non-null   float64
#  52  angular_offset_declination          5601 non-null   float64
#  53  angular_offset_sky                  5601 non-null   float64
#  54  insolation_flux                     5727 non-null   float64
#  55  star_density                        5727 non-null   float64
#  56  fp_total                            5881 non-null   int64
# dtypes: float64(47), int64(6), object(4)
# memory usage: 2.6+ MB

# %%
# Helper function which label encodes class based off of disposition and false positive flags
def encode_disposition(row):
    if row.disposition == 'CONFIRMED':
        return 0
    if row.fp_not_transit:
        return 1
    elif row.fp_stellar_eclipse:
        return 2
    elif row.fp_centroid_offset:
        return 3
    elif row.fp_contamination:
        return 4

# The data is relatively clean and none of the columns have good options for imputing - drop rows containing nans
# Create a classification column using above helper function, then drop unneeded columns
multi_class_df.dropna(inplace = True)
multi_class_df['classification'] = multi_class_df.apply(lambda x: int(encode_disposition(x)), axis = 1)
multi_class_df.drop(['koi_name', 'false_positive_type', 'fp_total', 'disposition',
                     'fp_not_transit', 'fp_stellar_eclipse', 'fp_centroid_offset', 'fp_contamination'],
                    axis = 1, inplace = True)
multi_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4260 entries, 0 to 9561
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ml_fittype                          4260 non-null   object
#  1   num_of_objects_around_star          4260 non-null   int64
#  2   right_ascension                     4260 non-null   float64
#  3   declination                         4260 non-null   float64
#  4   g_band_mag                          4260 non-null   float64
#  5   r_band_mag                          4260 non-null   float64
#  6   i_band_mag                          4260 non-null   float64
#  7   z_band_mag                          4260 non-null   float64
#  8   j_band_mag                          4260 non-null   float64
#  9   h_band_mag                          4260 non-null   float64
#  10  k_band_mag                          4260 non-null   float64
#  11  kepler_band_mag                     4260 non-null   float64
#  12  num_of_transits                     4260 non-null   float64
#  13  max_single_event_stat               4260 non-null   float64
#  14  max_multi_event_stat                4260 non-null   float64
#  15  odd_even_depth_stat                 4260 non-null   float64
#  16  limb_dark_co4                       4260 non-null   float64
#  17  limb_dark_co3                       4260 non-null   float64
#  18  limb_dark_co2                       4260 non-null   float64
#  19  limb_dark_co1                       4260 non-null   float64
#  20  transit_signal_to_noise             4260 non-null   float64
#  21  transit_epoch                       4260 non-null   float64
#  22  planet_radius_earth                 4260 non-null   float64
#  23  orbit_semimajor_axis                4260 non-null   float64
#  24  impact                              4260 non-null   float64
#  25  transit_duration                    4260 non-null   float64
#  26  transit_depth                       4260 non-null   float64
#  27  orbital_period                      4260 non-null   float64
#  28  planet_star_radius_ratio            4260 non-null   float64
#  29  planet_star_distance_radius         4260 non-null   float64
#  30  inclination                         4260 non-null   float64
#  31  planet_temp                         4260 non-null   float64
#  32  star_temp                           4260 non-null   float64
#  33  star_surface_gravity                4260 non-null   float64
#  34  star_metallicity                    4260 non-null   float64
#  35  star_radius                         4260 non-null   float64
#  36  star_mass                           4260 non-null   float64
#  37  flux_weight_offset_sig              4260 non-null   float64
#  38  centroid_right_ascension            4260 non-null   float64
#  39  centroid_declination                4260 non-null   float64
#  40  centroid_right_ascension_offset     4260 non-null   float64
#  41  centroid_declination_offset         4260 non-null   float64
#  42  planet_star_right_ascension_offset  4260 non-null   float64
#  43  planet_star_declination_offset      4260 non-null   float64
#  44  angular_offset_right_ascension      4260 non-null   float64
#  45  angular_offset_declination          4260 non-null   float64
#  46  angular_offset_sky                  4260 non-null   float64
#  47  insolation_flux                     4260 non-null   float64
#  48  star_density                        4260 non-null   float64
#  49  classification                      4260 non-null   int64
# dtypes: float64(47), int64(2), object(1)
# memory usage: 1.7+ MB

# %%
# Write dataframe to parquet file for further use
# multi_class_df.to_parquet('../data/cleaned/multi_class_data.parquet')

# %% [markdown]
# # Clean Binary Class Dataset

# %%
# Inspect binary_class_df
binary_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7510 entries, 0 to 9563
# Data columns (total 57 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   koi_name                            7510 non-null   object
#  1   disposition                         7510 non-null   object
#  2   false_positive_type                 6826 non-null   object
#  3   ml_fittype                          7510 non-null   object
#  4   num_of_objects_around_star          7510 non-null   int64
#  5   fp_not_transit                      7510 non-null   int64
#  6   fp_stellar_eclipse                  7510 non-null   int64
#  7   fp_centroid_offset                  7510 non-null   int64
#  8   fp_contamination                    7510 non-null   int64
#  9   right_ascension                     7510 non-null   float64
#  10  declination                         7510 non-null   float64
#  11  g_band_mag                          7476 non-null   float64
#  12  r_band_mag                          7503 non-null   float64
#  13  i_band_mag                          7383 non-null   float64
#  14  z_band_mag                          6993 non-null   float64
#  15  j_band_mag                          7485 non-null   float64
#  16  h_band_mag                          7485 non-null   float64
#  17  k_band_mag                          7485 non-null   float64
#  18  kepler_band_mag                     7509 non-null   float64
#  19  num_of_transits                     6829 non-null   float64
#  20  max_single_event_stat               6829 non-null   float64
#  21  max_multi_event_stat                6829 non-null   float64
#  22  odd_even_depth_stat                 6600 non-null   float64
#  23  limb_dark_co4                       7251 non-null   float64
#  24  limb_dark_co3                       7251 non-null   float64
#  25  limb_dark_co2                       7251 non-null   float64
#  26  limb_dark_co1                       7251 non-null   float64
#  27  transit_signal_to_noise             7251 non-null   float64
#  28  transit_epoch                       7510 non-null   float64
#  29  planet_radius_earth                 7251 non-null   float64
#  30  orbit_semimajor_axis                7251 non-null   float64
#  31  impact                              7251 non-null   float64
#  32  transit_duration                    7510 non-null   float64
#  33  transit_depth                       7251 non-null   float64
#  34  orbital_period                      7510 non-null   float64
#  35  planet_star_radius_ratio            7251 non-null   float64
#  36  planet_star_distance_radius         7251 non-null   float64
#  37  inclination                         7250 non-null   float64
#  38  planet_temp                         7251 non-null   float64
#  39  star_temp                           7251 non-null   float64
#  40  star_surface_gravity                7251 non-null   float64
#  41  star_metallicity                    7231 non-null   float64
#  42  star_radius                         7251 non-null   float64
#  43  star_mass                           7251 non-null   float64
#  44  flux_weight_offset_sig              6554 non-null   float64
#  45  centroid_right_ascension            7070 non-null   float64
#  46  centroid_declination                7070 non-null   float64
#  47  centroid_right_ascension_offset     7121 non-null   float64
#  48  centroid_declination_offset         7121 non-null   float64
#  49  planet_star_right_ascension_offset  6770 non-null   float64
#  50  planet_star_declination_offset      6794 non-null   float64
#  51  angular_offset_right_ascension      7003 non-null   float64
#  52  angular_offset_declination          7003 non-null   float64
#  53  angular_offset_sky                  7003 non-null   float64
#  54  insolation_flux                     7291 non-null   float64
#  55  star_density                        7291 non-null   float64
#  56  fp_total                            7510 non-null   int64
# dtypes: float64(47), int64(6), object(4)
# memory usage: 3.3+ MB

# %%
# Perform the same cleaning operations - drop unnecessary columns, drop rows with nans
binary_class_df.drop(['koi_name', 'false_positive_type', 'fp_total', 'fp_not_transit',
                      'fp_stellar_eclipse', 'fp_centroid_offset', 'fp_contamination'],
                    axis = 1, inplace = True)
binary_class_df.dropna(inplace = True)
binary_class_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5365 entries, 0 to 9563
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   disposition                         5365 non-null   object
#  1   ml_fittype                          5365 non-null   object
#  2   num_of_objects_around_star          5365 non-null   int64
#  3   right_ascension                     5365 non-null   float64
#  4   declination                         5365 non-null   float64
#  5   g_band_mag                          5365 non-null   float64
#  6   r_band_mag                          5365 non-null   float64
#  7   i_band_mag                          5365 non-null   float64
#  8   z_band_mag                          5365 non-null   float64
#  9   j_band_mag                          5365 non-null   float64
#  10  h_band_mag                          5365 non-null   float64
#  11  k_band_mag                          5365 non-null   float64
#  12  kepler_band_mag                     5365 non-null   float64
#  13  num_of_transits                     5365 non-null   float64
#  14  max_single_event_stat               5365 non-null   float64
#  15  max_multi_event_stat                5365 non-null   float64
#  16  odd_even_depth_stat                 5365 non-null   float64
#  17  limb_dark_co4                       5365 non-null   float64
#  18  limb_dark_co3                       5365 non-null   float64
#  19  limb_dark_co2                       5365 non-null   float64
#  20  limb_dark_co1                       5365 non-null   float64
#  21  transit_signal_to_noise             5365 non-null   float64
#  22  transit_epoch                       5365 non-null   float64
#  23  planet_radius_earth                 5365 non-null   float64
#  24  orbit_semimajor_axis                5365 non-null   float64
#  25  impact                              5365 non-null   float64
#  26  transit_duration                    5365 non-null   float64
#  27  transit_depth                       5365 non-null   float64
#  28  orbital_period                      5365 non-null   float64
#  29  planet_star_radius_ratio            5365 non-null   float64
#  30  planet_star_distance_radius         5365 non-null   float64
#  31  inclination                         5365 non-null   float64
#  32  planet_temp                         5365 non-null   float64
#  33  star_temp                           5365 non-null   float64
#  34  star_surface_gravity                5365 non-null   float64
#  35  star_metallicity                    5365 non-null   float64
#  36  star_radius                         5365 non-null   float64
#  37  star_mass                           5365 non-null   float64
#  38  flux_weight_offset_sig              5365 non-null   float64
#  39  centroid_right_ascension            5365 non-null   float64
#  40  centroid_declination                5365 non-null   float64
#  41  centroid_right_ascension_offset     5365 non-null   float64
#  42  centroid_declination_offset         5365 non-null   float64
#  43  planet_star_right_ascension_offset  5365 non-null   float64
#  44  planet_star_declination_offset      5365 non-null   float64
#  45  angular_offset_right_ascension      5365 non-null   float64
#  46  angular_offset_declination          5365 non-null   float64
#  47  angular_offset_sky                  5365 non-null   float64
#  48  insolation_flux                     5365 non-null   float64
#  49  star_density                        5365 non-null   float64
# dtypes: float64(47), int64(1), object(2)
# memory usage: 2.1+ MB

# %%
# Split into X and y dataframes to use LabelEncoder() on the target variable
# Reconvert back into dataframe - target variable 'disposition' encoded as 'CONFIRMED' = 0, 'FALSE POSITIVE' = 1
X_binary_class = binary_class_df.drop('disposition', axis = 1)
y_binary_class = binary_class_df.disposition

lec = LabelEncoder()

y_binary_class = pd.DataFrame(lec.fit_transform(y_binary_class),
                              index = y_binary_class.index,
                              columns = y_binary_class.to_frame().columns)

binary_class_df = pd.concat([X_binary_class, y_binary_class], axis = 1)
binary_class_df
# Out:
#      ml_fittype  num_of_objects_around_star  right_ascension  declination  \
# 0       LS+MCMC                           2        291.93423    48.141651
# 1       LS+MCMC                           2        291.93423    48.141651
# 3       LS+MCMC                           1        285.53461    48.285210
# 4       LS+MCMC                           1        288.75488    48.226200
# 8       LS+MCMC                           1        298.86435    42.151569
# ...         ...                         ...              ...          ...
# 9557    LS+MCMC                           1        290.93597    47.290730
# 9558    LS+MCMC                           1        298.74921    46.973351
# 9559    LS+MCMC                           1        297.18875    47.093819
# 9561    LS+MCMC                           1        294.16489    47.176281
# 9563    LS+MCMC                           1        297.00977    47.121021
#
#       g_band_mag  r_band_mag  i_band_mag  z_band_mag  j_band_mag  h_band_mag  \
# 0         15.890      15.270      15.114      15.006      14.082      13.751
# 1         15.890      15.270      15.114      15.006      14.082      13.751
# 3         16.100      15.554      15.382      15.266      14.326      13.911
# 4         16.015      15.468      15.292      15.241      14.366      14.064
# 8         12.999      12.609      12.515      12.480      11.659      11.415
# ...          ...         ...         ...         ...         ...         ...
# 9557      15.534      14.863      14.643      14.487      13.487      13.066
# 9558      15.064      14.441      14.227      14.144      13.153      12.847
# 9559      14.082      13.501      13.299      13.177      12.200      11.814
# 9561      15.853      15.347      15.185      15.158      14.220      13.913
# 9563      15.210      14.781      14.662      14.647      13.830      13.522
#
#       ...  centroid_right_ascension_offset  centroid_declination_offset  \
# 0     ...                            0.430                        0.940
# 1     ...                           -0.630                        1.230
# 3     ...                           -0.111                        0.002
# 4     ...                           -0.010                        0.230
# 8     ...                          -13.450                       24.090
# ...   ...                              ...                          ...
# 9557  ...                           -1.000                       -0.300
# 9558  ...                            1.100                        1.200
# 9559  ...                            0.792                       -0.484
# 9561  ...                            7.200                       -5.600
# 9563  ...                            2.900                        8.900
#
#       planet_star_right_ascension_offset  planet_star_declination_offset  \
# 0                              -0.000200                       -0.000550
# 1                               0.000660                       -0.001050
# 3                               0.003020                       -0.001420
# 4                               0.000080                       -0.000070
# 8                               0.003032                       -0.005549
# ...                                  ...                             ...
# 9557                            0.000600                        0.000300
# 9558                           -0.000080                       -0.000100
# 9559                           -0.000237                        0.000178
# 9561                           -0.000720                        0.000500
# 9563                           -0.000230                       -0.000700
#
#       angular_offset_right_ascension  angular_offset_declination  \
# 0                             -0.010                       0.200
# 1                              0.390                       0.000
# 3                             -0.249                       0.147
# 4                              0.030                      -0.090
# 8                             -4.506                       7.710
# ...                              ...                         ...
# 9557                           2.360                      -0.990
# 9558                           1.260                      -1.200
# 9559                           2.132                      -1.757
# 9561                           3.410                      -3.650
# 9563                           1.020                       3.300
#
#       angular_offset_sky  insolation_flux  star_density  disposition
# 0                  0.200            93.59       3.20796            0
# 1                  0.390             9.11       3.02368            0
# 3                  0.289           891.96       0.22080            1
# 4                  0.100           926.16       1.98635            0
# 8                  8.930           767.22       0.00485            1
# ...                  ...              ...           ...          ...
# 9557               2.550             0.42       0.00771            1
# 9558               1.750           176.40       0.18863            1
# 9559               2.763          4500.53       0.16318            1
# 9561               5.000          5713.41       8.97692            1
# 9563               3.400           607.42       1.40645            1
#
# [5365 rows x 50 columns]

# %%
# Write dataframe to parquet file for further use
# binary_class_df.to_parquet('../data/cleaned/binary_class_data.parquet')
